# %% [markdown]
# # MY JUPYTER NOTEBOOK

# %% [markdown]
# ANUJ SINGH YADAV
# My Current desire is to become a super rich Data Scientist

# %% [markdown]
# _I am Interested in data science beacuse in this morden era data is the new oil and everything from a tyer to a international space station everthing works on data._

# %% [markdown]
# ### In the next cell I will show how code executes.

# %%
print ("Hello world")
# Out:
# Hello world

# %%
2+2
# Out:
# 4

# %% [markdown]
# #### Ordered list

# %% [markdown]
# 1. cheese
# 2. anuj
# 3. sneha

# %% [markdown]
# #### Bulleted list

# %% [markdown]
# - Sneha
# - anuj
# - riya

# %% [markdown]
# #### Strike through

# %% [markdown]
# ~~Anujsinghyadav~~

# %% [markdown]
# #### Tables

# %% [markdown]
# | Header|Header|Heeader|
# |-------|------|-------|
# |-A      |-B     |C      |
# |X      |Y     |Z      |
